# %% [markdown]
# <a href="https://colab.research.google.com/github/Shariar076/notebook-snapshots/blob/main/rag_with_llama_or_gemma_and_faiss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installing Libraries

# %%
# %%capture
! pip install datasets pandas faiss-cpu sentence_transformers
! pip install "transformers>=4.45.1"
Install below if using GPU
! pip install -U accelerate
! pip install -U git+https://github.com/huggingface/peft
! pip install bitsandbytes
! pip install git+https://github.com/huggingface/transformers

# %%
import os
os.kill(os.getpid(), 9)

# %% [markdown]
# ## Data sourcing and preparation
#
#
# The data utilised in this tutorial is sourced from Hugging Face datasets, specifically the
# [AIatMongoDB/embedded_movies dataset](https://huggingface.co/datasets/AIatMongoDB/embedded_movies).

# %%
# Load Dataset
from datasets import load_dataset
import pandas as pd
import itertools

fullwiki_dataset = load_dataset("hotpotqa/hotpot_qa", 'distractor', trust_remote_code=True, split="validation[:500]")

# Convert the dataset to a pandas dataframe
dataset_df = pd.DataFrame(fullwiki_dataset)
# Convert the context column into a 1d list of sentences
dataset_df['context'] = dataset_df['context'].apply(lambda x: list(itertools.chain.from_iterable(x['sentences'])))
dataset_df.head(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
#                          id  \
# 0  5a8b57f25542995d1e6f1371
# 1  5a8c7595554299585d9e36b6
# 2  5a85ea095542994775f606a8
# 3  5adbf0a255429947ff17385a
# 4  5a8e3ea95542995a26add48d
#
#                                             question  \
# 0  Were Scott Derrickson and Ed Wood of the same ...
# 1  What government position was held by the woman...
# 2  What science fantasy young adult series, told ...
# 3  Are the Laleli Mosque and Esma Sultan Mansion ...
# 4  The director of the romantic comedy "Big Stone...
#
#                              answer        type level  \
# 0                               yes  comparison  hard
# 1                 Chief of Protocol      bridge  hard
# 2                         Animorphs      bridge  hard
# 3                                no  comparison  hard
# 4  Greenwich Village, New York City      bridge  hard
#
#                                     supporting_facts  \
# 0  {'title': ['Scott Derrickson', 'Ed Wood'], 'se...
# 1  {'title': ['Kiss and Tell (1945 film)', 'Shirl...
# 2  {'title': ['The Hork-Bajir Chronicles', 'The H...
# 3  {'title': ['Laleli Mosque', 'Esma Sultan Mansi...
# 4  {'title': ['Big Stone Gap (film)', 'Adriana Tr...
#
#                                              context
# 0  [Ed Wood is a 1994 American biographical perio...
# 1  [Meet Corliss Archer, a program from radio's G...
# 2  [The Andre Norton Award for Young Adult Scienc...
# 3  [Esma Sultan (21 March 1873 – 7 May 1899) was ...
# 4  [Just Another Romantic Wrestling Comedy is a 2...

# %% [markdown]
# ## Create a document dataframe using the contexts

# %%
# Find the unique docs by further flattenning the contexts
document_df = pd.DataFrame()
document_df['doc'] =  pd.Series(itertools.chain.from_iterable(dataset_df['context'].values)).unique()
document_df = document_df[document_df['doc'].str.len() > 0]
document_df
# Out:
#                                                      doc
# 0        Adam Collis is an American filmmaker and actor.
# 1       He attended the Duke University from 1986 to ...
# 2       He also studied cinema at the University of S...
# 3       Collis first work was the assistant director ...
# 4       In 1998, he played "Crankshaft" in Eric Koyan...
# ...                                                  ...
# 21011   Ako recently played “Klook” in “Klook’s Last ...
# 21012   He also recently played esteemed British acto...
# 21013   Ako has also worked at London’s Donmar Wareho...
# 21014   Ako’s credits also include: Pilot in Nick Llo...
# 21015   Ako also Co-produced the documentary film 500...
#
# [21015 rows x 1 columns]

# %% [markdown]
# ## Data Preparation

# %%
# Remove data point where plot coloumn is missing
dataset_df = dataset_df.dropna(subset=["context"])
print("\nNumber of missing values in each column after removal:")
print(dataset_df.isnull().sum())

# Remove the plot_embedding from each data point in the dataset as we are going to create new embeddings with an open source embedding model from Hugging Face
# document_df = document_df.drop(columns=["context_embedding"])
# document_df.head(5)
# Out:
# Number of missing values in each column after removal:
# id                  0
# question            0
# answer              0
# type                0
# level               0
# supporting_facts    0
# context             0
# dtype: int64

# %% [markdown]
# ## Generating embeddings
#
# **The steps in the code snippets are as follows:**
# 1. Import the `SentenceTransformer` class to access the embedding models.
# 2. Load the embedding model using the `SentenceTransformer` constructor to instantiate the `gte-large` embedding model.
# 3. Define the `get_embedding` function, which takes a text string as input and returns a list of floats representing the embedding. The function first checks if the input text is not empty (after stripping whitespace). If the text is empty, it returns an empty list. Otherwise, it generates an embedding using the loaded model.
# 4. Generate embeddings by applying the `get_embedding` function to the "fullplot" column of the `dataset_df` DataFrame, generating embeddings for each movie's plot. The resulting list of embeddings is assigned to a new column named embedding.
#
# *Note: It's not necessary to chunk the text in the full plot, as we can ensure that the text length remains within a manageable range.*

# %%
import faiss

from sentence_transformers import SentenceTransformer

# https://huggingface.co/thenlper/gte-large
embedding_model = SentenceTransformer("thenlper/gte-large")

docs = document_df['doc'].to_numpy()
embeddings = embedding_model.encode(docs)
print(embeddings.shape)
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)
# Out:
# (21015, 1024)
#                                                  doc  embedding
# 0    Adam Collis is an American filmmaker and actor.   0.001379
# 1   He attended the Duke University from 1986 to ...  -0.011071
# 2   He also studied cinema at the University of S...   0.013232
# 3   Collis first work was the assistant director ...  -0.007571
# 4   In 1998, he played "Crankshaft" in Eric Koyan...   0.015223

# %%
import pickle
pickle.dump(embeddings, open(f"hotpotqa_embeddings.pkl", "wb"))

# %% [markdown]
# ## Perform Vector Search on User Queries

# %%
from functools import partial

def vector_index_search(user_query, k):
    query_embedding = embedding_model.encode([user_query])
    D, I = index.search(query_embedding, k)
    return document_df.iloc[I[0]].values


dataset_df['top_1'] = dataset_df['question'].apply(vector_index_search, k=1)
dataset_df['top_3'] = dataset_df['question'].apply(vector_index_search, k=3)
dataset_df['top_5'] = dataset_df['question'].apply(vector_index_search, k=5)


dataset_df
# Out:
#                            id  \
# 0    5a8b57f25542995d1e6f1371
# 1    5a8c7595554299585d9e36b6
# 2    5a85ea095542994775f606a8
# 3    5adbf0a255429947ff17385a
# 4    5a8e3ea95542995a26add48d
# ..                        ...
# 495  5a79b7f6554299029c4b5f6f
# 496  5ab626d555429953192ad279
# 497  5a84873e5542997175ce1eec
# 498  5ac537975542996feb3fea3c
# 499  5a8f45ca5542997ba9cb320e
#
#                                               question  \
# 0    Were Scott Derrickson and Ed Wood of the same ...
# 1    What government position was held by the woman...
# 2    What science fantasy young adult series, told ...
# 3    Are the Laleli Mosque and Esma Sultan Mansion ...
# 4    The director of the romantic comedy "Big Stone...
# ..                                                 ...
# 495  How many restaurants comprise the quick servic...
# 496  Anthony Avent played basketball fo a High Scho...
# 497  What edition of tennis' US Open was the 2017 U...
# 498  Walt Zeboski photographed which 40th President...
# 499  What type of film are both "500 Years Later" a...
#
#                                answer        type level  \
# 0                                 yes  comparison  hard
# 1                   Chief of Protocol      bridge  hard
# 2                           Animorphs      bridge  hard
# 3                                  no  comparison  hard
# 4    Greenwich Village, New York City      bridge  hard
# ..                                ...         ...   ...
# 495                             4,613      bridge  hard
# 496                   lower Manhattan      bridge  hard
# 497                             137th      bridge  hard
# 498              Ronald Wilson Reagan      bridge  hard
# 499                       documentary  comparison  hard
#
#                                       supporting_facts  \
# 0    {'title': ['Scott Derrickson', 'Ed Wood'], 'se...
# 1    {'title': ['Kiss and Tell (1945 film)', 'Shirl...
# 2    {'title': ['The Hork-Bajir Chronicles', 'The H...
# 3    {'title': ['Laleli Mosque', 'Esma Sultan Mansi...
# 4    {'title': ['Big Stone Gap (film)', 'Adriana Tr...
# ..                                                 ...
# 495  {'title': ['Ron Joyce', 'Ron Joyce', 'Tim Hort...
# 496  {'title': ['Anthony Avent', 'Anthony Avent', '...
# 497  {'title': ['Petra Kvitová career statistics', ...
# 498  {'title': ['Walt Zeboski', 'Ronald Reagan'], '...
# 499  {'title': ['500 Years Later', 'Manson (film)']...
#
#                                                context  \
# 0    [Adam Collis is an American filmmaker and acto...
# 1    [A Kiss for Corliss is a 1949 American comedy ...
# 2    [Animorphs is a science fantasy series of youn...
# 3    [Esma Sultan is the name of three daughters of...
# 4    [Great Eastern Conventions, Inc. was an entert...
# ..                                                 ...
# 495  [Arcos Dorados Holdings Inc. is McDonald’s lar...
# 496  [Locust Lake State Park is a Pennsylvania stat...
# 497  [The 2017 Winston–Salem Open was a men's tenni...
# 498  [Bernhard Vogel (born 19 December 1932) is a G...
# 499  [Kyokusui-no-en (曲水の宴 ("Winding stream party" ...
#
#                                                  top_1  \
# 0    [[Ed Wood is a 1994 American biographical peri...
# 1    [[Kiss and Tell is a 1945 American comedy film...
# 2    [[ It is told in first person, with all six ma...
# 3    [[The Esma Sultan Mansion (Turkish: "Esma Sult...
# 4    [[Big Stone Gap is a 2014 American drama roman...
# ..                                                 ...
# 495  [[ It is also Canada's largest quick service r...
# 496  [[Anthony Avent (born October 18, 1969) is a r...
# 497  [[ It was the last event of the 2017 US Open S...
# 498  [[ Zeboski extensively photographed Ronald Rea...
# 499  [[500 Years Later (፭፻ ዓመታት በኋላ "500 ʿamätatə b...
#
#                                                  top_3  \
# 0    [[Ed Wood is a 1994 American biographical peri...
# 1    [[Kiss and Tell is a 1945 American comedy film...
# 2    [[ It is told in first person, with all six ma...
# 3    [[The Esma Sultan Mansion (Turkish: "Esma Sult...
# 4    [[Big Stone Gap is a 2014 American drama roman...
# ..                                                 ...
# 495  [[ It is also Canada's largest quick service r...
# 496  [[Anthony Avent (born October 18, 1969) is a r...
# 497  [[ It was the last event of the 2017 US Open S...
# 498  [[ Zeboski extensively photographed Ronald Rea...
# 499  [[500 Years Later (፭፻ ዓመታት በኋላ "500 ʿamätatə b...
#
#                                                  top_5
# 0    [[Ed Wood is a 1994 American biographical peri...
# 1    [[Kiss and Tell is a 1945 American comedy film...
# 2    [[ It is told in first person, with all six ma...
# 3    [[The Esma Sultan Mansion (Turkish: "Esma Sult...
# 4    [[Big Stone Gap is a 2014 American drama roman...
# ..                                                 ...
# 495  [[ It is also Canada's largest quick service r...
# 496  [[Anthony Avent (born October 18, 1969) is a r...
# 497  [[ It was the last event of the 2017 US Open S...
# 498  [[ Zeboski extensively photographed Ronald Rea...
# 499  [[500 Years Later (፭፻ ዓመታት በኋላ "500 ʿamätatə b...
#
# [500 rows x 10 columns]

# %%
dataset_df.to_csv("hotpotqa_retieval_results.csv", index=False)

# %% [markdown]
# ## Evaluation

# %%
# from transformers import AutoTokenizer, AutoModelForCausalLM

# tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
# model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it", device_map="auto")

# %%
import huggingface_hub
huggingface_hub.login('')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import PeftModel

# model_name = "meta-llama/Llama-3.1-8B-Instruct"
model_name = "google/gemma-2-2b-it"

# adapter_name = "shariar076/Llama-3.1-8B-Instruct-hotpotqa-raft-1000_adapter"
adapter_name = "shariar076/gemma-2-2b-hotpotqa-raft-1k_adapter"

tokenizer = AutoTokenizer.from_pretrained(model_name)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    # load_in_8bit=use_8_bit,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=getattr(torch, "bfloat16"),
    bnb_4bit_use_double_quant=True,
)

model = AutoModelForCausalLM.from_pretrained(model_name,
                                             quantization_config=bnb_config,
                                             torch_dtype=torch.float16,
                                             # attn_implementation="flash_attention_2",
                                             device_map='auto')

model = PeftModel.from_pretrained(
        model,
        adapter_name,
        torch_dtype=torch.float16
    )
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## Default Dataset

# %%
tokenizer.pad_token = tokenizer.eos_token


def batch_generate(rows):
  user_queries = rows['question']
  search_results = rows['context']
  instruction = "Given the question and context above, please provide one logical reasoning and one answer. Please use the format:\n\n##Reasoning: {reasoning}\n\n##Answer: {answer}."
  prompts = [f"Question: {q}\n\nContext: {c}\n\nInstruction: {instruction}" for q, c in zip(user_queries, search_results)]
  input_ids = tokenizer(prompts, padding=True, return_tensors="pt").to("cuda")
  with torch.no_grad():
    generated_ids = model.generate(**input_ids, max_new_tokens=512)
  outputs =tokenizer.batch_decode(generated_ids, skip_special_tokens=True) #, skip_special_tokens=True

  # return {'generated_answer': outputs}
  return outputs

# %%
import re
from tqdm.notebook import tqdm
from datasets import Dataset

all_generated_answers = []
batch_size = 8

for i in tqdm(range(0, len(dataset_df), batch_size)):
    batch = dataset_df[i:i + batch_size]
    generated_answers = batch_generate(batch)
    all_generated_answers.extend(generated_answers)
# dataset = Dataset.from_pandas(dataset_df)
# dataset = dataset.map(batch_generate, batched=True, batch_size=batch_size)
# dataset

answers = []
for index, output in enumerate(all_generated_answers):
  # if index==1:
  #   print(output)
  answer = re.split('[.\n]', output.split('##Answer:')[-1])[0].strip()
  answers.append(answer)

dataset_df['answer_pred'] = answers
dataset_df[['answer', 'answer_pred']]
# Out:
#   0%|          | 0/63 [00:00<?, ?it/s]
#                                answer  \
# 0                                 yes
# 1                   Chief of Protocol
# 2                           Animorphs
# 3                                  no
# 4    Greenwich Village, New York City
# ..                                ...
# 495                             4,613
# 496                   lower Manhattan
# 497                             137th
# 498              Ronald Wilson Reagan
# 499                       documentary
#
#                                            answer_pred
# 0                                   Both were American
# 1                                  Meet Corliss Archer
# 2                                             {answer}
# 3                                                  Yes
# 4    The context does not provide any specific info...
# ..                                                 ...
# 495                                                  1
# 496        Seton Hall University in Newark, New Jersey
# 497                                       2017 US Open
# 498                                      Ronald Reagan
# 499                                      documentaries
#
# [500 rows x 2 columns]

# %%
ds_acc = (dataset_df.answer_pred.str.extract(r'(\w+)', expand=False).str.lower()==dataset_df.answer.str.extract(r'(\w+)', expand=False).str.lower()).mean()
print("ds_acc", ds_acc*100)
# Out:
# ds_acc 34.0

# %%
dataset_df.to_csv("hotpotqa_gemma-2-2b-it_distractor_cot_ft_results.csv", index = False)

# %% [markdown]
# ## FAISS Retrieved

# %%
import pandas as pd

dataset_df = pd.read_csv("hotpotqa_retieval_results.csv", index_col='id')
# dataset_df = pd.read_csv("hotpotqa_llama-3.1-8B-instruct_no_cot_results.csv")
dataset_df.head(5)
# Out:
#                                                                    question  \
# id
# 5a8b57f25542995d1e6f1371  Were Scott Derrickson and Ed Wood of the same ...
# 5a8c7595554299585d9e36b6  What government position was held by the woman...
# 5a85ea095542994775f606a8  What science fantasy young adult series, told ...
# 5adbf0a255429947ff17385a  Are the Laleli Mosque and Esma Sultan Mansion ...
# 5a8e3ea95542995a26add48d  The director of the romantic comedy "Big Stone...
#
#                                                     answer        type level  \
# id
# 5a8b57f25542995d1e6f1371                               yes  comparison  hard
# 5a8c7595554299585d9e36b6                 Chief of Protocol      bridge  hard
# 5a85ea095542994775f606a8                         Animorphs      bridge  hard
# 5adbf0a255429947ff17385a                                no  comparison  hard
# 5a8e3ea95542995a26add48d  Greenwich Village, New York City      bridge  hard
#
#                                                            supporting_facts  \
# id
# 5a8b57f25542995d1e6f1371  {'title': ['Scott Derrickson', 'Ed Wood'], 'se...
# 5a8c7595554299585d9e36b6  {'title': ['Kiss and Tell (1945 film)', 'Shirl...
# 5a85ea095542994775f606a8  {'title': ['The Hork-Bajir Chronicles', 'The H...
# 5adbf0a255429947ff17385a  {'title': ['Laleli Mosque', 'Esma Sultan Mansi...
# 5a8e3ea95542995a26add48d  {'title': ['Big Stone Gap (film)', 'Adriana Tr...
#
#                                                                     context  \
# id
# 5a8b57f25542995d1e6f1371  ['Adam Collis is an American filmmaker and act...
# 5a8c7595554299585d9e36b6  ['A Kiss for Corliss is a 1949 American comedy...
# 5a85ea095542994775f606a8  ['Animorphs is a science fantasy series of you...
# 5adbf0a255429947ff17385a  ['Esma Sultan is the name of three daughters o...
# 5a8e3ea95542995a26add48d  ['Great Eastern Conventions, Inc. was an enter...
#
#                                                                       top_1  \
# id
# 5a8b57f25542995d1e6f1371  [['Ed Wood is a 1994 American biographical per...
# 5a8c7595554299585d9e36b6  [['Kiss and Tell is a 1945 American comedy fil...
# 5a85ea095542994775f606a8  [[' It is told in first person, with all six m...
# 5adbf0a255429947ff17385a  [['The Esma Sultan Mansion (Turkish: "Esma Sul...
# 5a8e3ea95542995a26add48d  [['Big Stone Gap is a 2014 American drama roma...
#
#                                                                       top_3  \
# id
# 5a8b57f25542995d1e6f1371  [['Ed Wood is a 1994 American biographical per...
# 5a8c7595554299585d9e36b6  [['Kiss and Tell is a 1945 American comedy fil...
# 5a85ea095542994775f606a8  [[' It is told in first person, with all six m...
# 5adbf0a255429947ff17385a  [['The Esma Sultan Mansion (Turkish: "Esma Sul...
# 5a8e3ea95542995a26add48d  [['Big Stone Gap is a 2014 American drama roma...
#
#                                                                       top_5
# id
# 5a8b57f25542995d1e6f1371  [['Ed Wood is a 1994 American biographical per...
# 5a8c7595554299585d9e36b6  [['Kiss and Tell is a 1945 American comedy fil...
# 5a85ea095542994775f606a8  [[' It is told in first person, with all six m...
# 5adbf0a255429947ff17385a  [['The Esma Sultan Mansion (Turkish: "Esma Sul...
# 5a8e3ea95542995a26add48d  [['Big Stone Gap is a 2014 American drama roma...

# %%
import re
def generate_answer(row, k):
  user_query = row['question']
  search_results = row[f'top_{k}']
  # prompt = f"Query: {user_query}\nProvide answer to the query by using the Search Results:\n{search_results}\n\n."+" Please use the format: Answer:{only answer with no explanation}"
  instruction = "Given the question and context above, please provide one logical reasoning and one answer. Please use the format:\n\n##Reasoning: {reasoning}\n\n##Answer: {answer}."
  prompt = f"Question: {user_query}\n\nContext: {search_results}\n\nInstruction: {instruction}"
  input_ids = tokenizer(prompt, return_tensors="pt").to("cuda")
  response = model.generate(**input_ids, max_new_tokens=512)
  output =tokenizer.decode(response[0]) #, skip_special_tokens=True
  # print("="*100)
  # print(output)
  # print("="*100)
  try:
    # answer = re.sub(r'[^A-Za-z0-9 ]+', '', output.split('##Answer:')[-1].split('.')[0]).strip()
    answer = output.split('##Answer:')[-1].split('[.\n]')[0].strip()
  except:
    answer = output
  return answer

# %%
tokenizer.pad_token = tokenizer.eos_token

def batch_generate(rows, k):
  user_queries = rows['question']
  search_results = rows[f'top_{k}']
  instruction = "Given the question and context above, please provide one logical reasoning and one answer. Please use the format:\n\n##Reasoning: {reasoning}\n\n##Answer: {answer}."
  prompts = [f"Question: {q}\n\nContext: {c}\n\nInstruction: {instruction}" for q, c in zip(user_queries, search_results)]
  input_ids = tokenizer(prompts, padding=True, return_tensors="pt").to("cuda")
  with torch.no_grad():
    generated_ids = model.generate(**input_ids, max_new_tokens=512)
  outputs =tokenizer.batch_decode(generated_ids, skip_special_tokens=True) #, skip_special_tokens=True

  return outputs

# %%
batch_generate(dataset_df[100:101], 1)

# %%
# dataset_df['answer_k_1'] = dataset_df.apply(generate_answer, k=1, axis=1)
import re
from tqdm.notebook import tqdm

all_generated_answers = []
batch_size = 64
for i in tqdm(range(0, len(dataset_df), batch_size)):
    batch = dataset_df[i:i + batch_size]
    generated_answers = batch_generate(batch, k=1)
    all_generated_answers.extend(generated_answers)

answers = []
for index, output in enumerate(all_generated_answers):
  # if index==1:
  #   print(output)
  answer = re.split('[.\n]', output.split('##Answer:')[-1])[0].strip()
  answers.append(answer)

dataset_df['answer_k_1'] = answers
dataset_df[['answer', 'answer_k_1']]

# dataset_df.answer.str.extract(r'(\w+)', expand=False).str.lower().head(10)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#                                                     answer  \
# id
# 5a8b57f25542995d1e6f1371                               yes
# 5a8c7595554299585d9e36b6                 Chief of Protocol
# 5a85ea095542994775f606a8                         Animorphs
# 5adbf0a255429947ff17385a                                no
# 5a8e3ea95542995a26add48d  Greenwich Village, New York City
# ...                                                    ...
# 5a79b7f6554299029c4b5f6f                             4,613
# 5ab626d555429953192ad279                   lower Manhattan
# 5a84873e5542997175ce1eec                             137th
# 5ac537975542996feb3fea3c              Ronald Wilson Reagan
# 5a8f45ca5542997ba9cb320e                       documentary
#
#                                                                  answer_k_1
# id
# 5a8b57f25542995d1e6f1371                                Ed Wood is American
# 5a8c7595554299585d9e36b6                                     Shirley Temple
# 5a85ea095542994775f606a8  The series you are describing is likely "The H...
# 5adbf0a255429947ff17385a  No, the Laleli Mosque is not located in the sa...
# 5a8e3ea95542995a26add48d                                      New York City
# ...                                                                     ...
# 5a79b7f6554299029c4b5f6f                                              4,613
# 5ab626d555429953192ad279
# 5a84873e5542997175ce1eec                                               2017
# 5ac537975542996feb3fea3c                                      Ronald Reagan
# 5a8f45ca5542997ba9cb320e
#
# [500 rows x 2 columns]

# %%
k_1_acc = (dataset_df.answer_k_1.str.extract(r'(\w+)', expand=False).str.lower()==dataset_df.answer.str.extract(r'(\w+)', expand=False).str.lower()).mean()
print("k_1_acc", k_1_acc*100)
# Out:
# k_1_acc 22.0

# %%
# dataset_df['answer_k_3'] = dataset_df.apply(generate_answer, k=3, axis=1)
import re
from tqdm.notebook import tqdm

all_generated_answers = []
batch_size = 64
for i in tqdm(range(0, len(dataset_df), batch_size)):
    batch = dataset_df[i:i + batch_size]
    generated_answers = batch_generate(batch, k=3)
    all_generated_answers.extend(generated_answers)

answers = []
for index, output in enumerate(all_generated_answers):
  # if index==1:
  #   print(output)
  answer = re.split('[.\n]', output.split('##Answer:')[-1])[0].strip()
  answers.append(answer)

dataset_df['answer_k_3'] = answers
dataset_df[['answer', 'answer_k_3']]
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#                                                     answer  \
# id
# 5a8b57f25542995d1e6f1371                               yes
# 5a8c7595554299585d9e36b6                 Chief of Protocol
# 5a85ea095542994775f606a8                         Animorphs
# 5adbf0a255429947ff17385a                                no
# 5a8e3ea95542995a26add48d  Greenwich Village, New York City
# ...                                                    ...
# 5a79b7f6554299029c4b5f6f                             4,613
# 5ab626d555429953192ad279                   lower Manhattan
# 5a84873e5542997175ce1eec                             137th
# 5ac537975542996feb3fea3c              Ronald Wilson Reagan
# 5a8f45ca5542997ba9cb320e                       documentary
#
#                                                                  answer_k_3
# id
# 5a8b57f25542995d1e6f1371
# 5a8c7595554299585d9e36b6  Shirley Temple was a child actress who was fam...
# 5a85ea095542994775f606a8
# 5adbf0a255429947ff17385a
# 5a8e3ea95542995a26add48d  We cannot answer this question based on the pr...
# ...                                                                     ...
# 5a79b7f6554299029c4b5f6f                                              4,613
# 5ab626d555429953192ad279
# 5a84873e5542997175ce1eec
# 5ac537975542996feb3fea3c
# 5a8f45ca5542997ba9cb320e
#
# [500 rows x 2 columns]

# %%
k_3_acc = (dataset_df.answer_k_3.str.extract(r'(\w+)', expand=False).str.lower()==dataset_df.answer.str.extract(r'(\w+)', expand=False).str.lower()).mean()
print("k_3_acc", k_3_acc*100)
# Out:
# k_3_acc 17.2

# %%
# dataset_df['answer_k_5'] = dataset_df.apply(generate_answer, k=5, axis=1)
import re
from tqdm.notebook import tqdm

all_generated_answers = []
batch_size = 64
for i in tqdm(range(0, len(dataset_df), batch_size)):
    batch = dataset_df[i:i + batch_size]
    generated_answers = batch_generate(batch, k=5)
    all_generated_answers.extend(generated_answers)

answers = []
for index, output in enumerate(all_generated_answers):
  # if index==1:
  #   print(output)
  answer = re.split('[.\n]', output.split('##Answer:')[-1])[0].strip()
  answers.append(answer)

dataset_df['answer_k_5'] = answers
dataset_df[['answer', 'answer_k_5']]
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#                                                     answer  \
# id
# 5a8b57f25542995d1e6f1371                               yes
# 5a8c7595554299585d9e36b6                 Chief of Protocol
# 5a85ea095542994775f606a8                         Animorphs
# 5adbf0a255429947ff17385a                                no
# 5a8e3ea95542995a26add48d  Greenwich Village, New York City
# ...                                                    ...
# 5a79b7f6554299029c4b5f6f                             4,613
# 5ab626d555429953192ad279                   lower Manhattan
# 5a84873e5542997175ce1eec                             137th
# 5ac537975542996feb3fea3c              Ronald Wilson Reagan
# 5a8f45ca5542997ba9cb320e                       documentary
#
#                                                                  answer_k_5
# id
# 5a8b57f25542995d1e6f1371
# 5a8c7595554299585d9e36b6
# 5a85ea095542994775f606a8
# 5adbf0a255429947ff17385a
# 5a8e3ea95542995a26add48d  We cannot determine the director's location ba...
# ...                                                                     ...
# 5a79b7f6554299029c4b5f6f                                                 27
# 5ab626d555429953192ad279                                 Newark, New Jersey
# 5a84873e5542997175ce1eec
# 5ac537975542996feb3fea3c
# 5a8f45ca5542997ba9cb320e
#
# [500 rows x 2 columns]

# %%
k_5_acc = (dataset_df.answer_k_5.str.extract(r'(\w+)', expand=False).str.lower()==dataset_df.answer.str.extract(r'(\w+)', expand=False).str.lower()).mean()
print("k_5_acc", k_5_acc*100)
# Out:
# k_5_acc 17.4

# %%
dataset_df.to_csv("hotpotqa_gemma-2-2b-it_no_cot_results.csv", index = False)
